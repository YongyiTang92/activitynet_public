# %%
from matplotlib.pyplot import imshow
# %matplotlib inline
import numpy as np
import tensorflow as tf
from tensorflow.python.platform import gfile
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
import os
sess = tf.InteractiveSession()

# %%
filenames = gfile.Glob(os.path.join('./output', '*.tfrecords'))
filename_queue = tf.train.string_input_producer(filenames, shuffle=False)
reader = tf.TFRecordReader()
serialized_key, serialized_example = reader.read(filename_queue)
features = tf.parse_single_example(serialized_example, features={  
    'images': tf.FixedLenFeature([], tf.string)
    })

# %%
image = tf.decode_raw(features['images'], tf.uint8)
image_raw = tf.image.decode_jpeg(features['images'], channels=3)

# %%
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(coord=coord)
image_raw.eval()
# Out:
# array([[[ 0,  1,  5],
#         [ 0,  1,  5],
#         [ 0,  1,  5],
#         ...,
#         [ 3,  0,  2],
#         [ 3,  0,  2],
#         [ 3,  0,  2]],
#
#        [[ 0,  0,  5],
#         [ 0,  0,  5],
#         [ 0,  0,  5],
#         ...,
#         [ 3,  0,  2],
#         [ 3,  0,  2],
#         [ 3,  0,  2]],
#
#        [[ 0,  0,  5],
#         [ 0,  0,  5],
#         [ 0,  0,  5],
#         ...,
#         [ 1,  0,  2],
#         [ 1,  0,  2],
#         [ 1,  0,  2]],
#
#        ...,
#
#        [[ 6,  0,  5],
#         [ 6,  0,  5],
#         [ 6,  0,  5],
#         ...,
#         [ 4,  0,  9],
#         [ 4,  0,  9],
#         [ 4,  0,  9]],
#
#        [[ 6,  0,  7],
#         [ 6,  0,  7],
#         [ 6,  0,  7],
#         ...,
#         [ 4,  0, 11],
#         [ 4,  0, 11],
#         [ 4,  0, 11]],
#
#        [[ 6,  0,  7],
#         [ 6,  0,  7],
#         [ 6,  0,  7],
#         ...,
#         [ 4,  0, 11],
#         [ 4,  0, 11],
#         [ 4,  0, 11]]], dtype=uint8)

# %%
image = tf.image.resize_image_with_crop_or_pad(image_raw, 240, 320)

# %%
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)
    print("Write cropped and resized image to the folder './resized_image'") 
    for i in range(10): # number of examples in your tfrecord
        pre_image = sess.run(image_raw)
        img = Image.fromarray(pre_image, "RGB")
#         print(img.shape)
        imshow(img)
#         if not os.path.isdir("./resized_image/"):
#             os.mkdir("./resized_image")
#         img.save(os.path.join("./resized_image/class_"+str(pre_label)+"_Index_"+str(i)+".jpeg"))
#         if i % 10 == 0:
#             print ("%d images in %d has finished!" % (i, FLAGS.image_number))
#     print("Complete!!")
    coord.request_stop()
    coord.join(threads)
    sess.close()
# Out:
# Write cropped and resized image to the folder './resized_image'

# %%
with tf.Session() as sess:
#     image = tf.image.decode_jpeg(features['images'], channels=3)
#     img_data_jpg = tf.image.convert_image_dtype(image, dtype=tf.uint8)
    imshow(features['images'].eval())

# %%
def build_tfrecord_input(training=True):
  filenames = gfile.Glob(os.path.join('./output', '*'))
  filename_queue = tf.train.string_input_producer(filenames, shuffle=True)

  reader = tf.TFRecordReader()
  _, serialized_example = reader.read(filename_queue)
  image_seq, state_seq, action_seq = [], [], []

  for i in range(FLAGS.sequence_length):

    image_name = 'move/' + str(i) + '/image/encoded'
    features = {image_name: tf.FixedLenFeature([], tf.string)}
    features = tf.parse_single_example(serialized_example, features=features)
    # image = tf.decode_raw(features[image_name], tf.uint8)
    image = tf.image.decode_jpg(features[image_name], channels=COLOR_CHAN)
    print(repr(image))
    SHAPE = tf.pack([ORIGINAL_HEIGHT,ORIGINAL_WIDTH,COLOR_CHAN])
    image = tf.reshape(image, SHAPE)
    print(repr(image))
    # image.set_shape([ORIGINAL_HEIGHT, ORIGINAL_WIDTH, COLOR_CHAN])
    image = tf.Print(image, [SHAPE])

    if IMG_HEIGHT != IMG_WIDTH:
      raise ValueError('Unequal height and width unsupported')

    crop_size = min(ORIGINAL_HEIGHT, ORIGINAL_WIDTH)
    image = tf.image.resize_image_with_crop_or_pad(image, crop_size, crop_size)
    image = tf.reshape(image, [1, crop_size, crop_size, COLOR_CHAN])
    image = tf.image.resize_bicubic(image, [IMG_HEIGHT, IMG_WIDTH])
    image = tf.cast(image, tf.float32) / 255.0
    print(repr(image))
    image_seq.append(image)

  image_seq = tf.concat(0, image_seq)
  image_batch = tf.train.batch(
      [image_seq],
      FLAGS.batch_size,
      num_threads=FLAGS.batch_size,
      capacity=100 * FLAGS.batch_size)
  zeros_batch = tf.zeros([FLAGS.batch_size, FLAGS.sequence_length, STATE_DIM])
  return image_batch, zeros_batch, zeros_batch

# %% [markdown]
# ## Test Varlen images

# %%
filenames = gfile.Glob(os.path.join('./output/videos', '*.tfrecords'))
filename_queue = tf.train.string_input_producer(filenames, shuffle=False)
reader = tf.TFRecordReader()
serialized_key, serialized_example = reader.read(filename_queue)
features = tf.parse_single_example(serialized_example, features={  
    'frames': tf.FixedLenFeature([], tf.int64),
    'images': tf.VarLenFeature(tf.string)
    })

# %%
images =features['images']

# %%
frames = tf.cast(features['frames'], tf.int32)
images_shape = tf.parallel_stack([frames])
images = tf.reshape(images.values, images_shape)

# %%
image_raw = tf.image.decode_jpeg(images[1200], channels=3)

# %%
frame_nums = 16


start = tf.random_uniform(frames.shape, minval=0, maxval=frames-frame_nums, dtype=tf.int32, seed=None, name=None)

image_list = []
for i in range(frame_nums):
    image_raw = tf.image.decode_jpeg(images[start+i], channels=3)
    image_list.append(image_raw)



# i = tf.constant(0)
# while_condition = lambda i: tf.less(i, start)
# image_list = []
# def body(i):
#     image_raw = tf.image.decode_jpeg(images[i], channels=3)
#     image_list.append(image_raw)
#     i = i +1
#     return i
# #     i = i+1
# sample_frames = tf.range(0, frames, 1)
# out = images[start]
# out=tf.slice(images,start,1) 
# image_raw = tf.image.decode_jpeg(out, channels=3)

# r = tf.while_loop(while_condition, body, [i])

# %%
images.shape
# Out:
# TensorShape([Dimension(None), Dimension(None)])

# %%
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)
    print("Write cropped and resized image to the folder './resized_image'") 
    for i in range(10): # number of examples in your tfrecord
#         images_run = sess.run(images)
#         pre_image = sess.run(image_raw)
        image_list_ = sess.run(image_list)
#         img = Image.fromarray(pre_image, "RGB")
#         print(img.shape)
#         imshow(img)
#         if not os.path.isdir("./resized_image/"):
#             os.mkdir("./resized_image")
#         img.save(os.path.join("./resized_image/class_"+str(pre_label)+"_Index_"+str(i)+".jpeg"))
#         if i % 10 == 0:
#             print ("%d images in %d has finished!" % (i, FLAGS.image_number))
#     print("Complete!!")
    coord.request_stop()
    coord.join(threads)
    sess.close()
# Out:
# Write cropped and resized image to the folder './resized_image'

# %%
images_run.shape
# Out:
# (1458,)

# %%
img = Image.fromarray(image_list_[-1], "RGB")
imshow(img)

# %% [markdown]
# # Test JSON file

# %%
import json

# %%
with open("./activity_net.v1-3.min.json", 'r') as fobj:
    gd_data = json.load(fobj)

# %%
gd_data
# Out:
# dict_keys(['taxonomy', 'version', 'database'])

# %%
len(gd_data['database'])
# Out:
# 19994

# %%
gd_data['database']['5n7NCViB5TU']
# Out:
# {'annotations': [{'label': 'Discus throw',
#    'segment': [24.250181653524645, 38.08036312324492]},
#   {'label': 'Discus throw', 'segment': [62.14109007176286, 71.61381721684867]},
#   {'label': 'Discus throw',
#    'segment': [97.00072596567863, 106.28399856786271]}],
#  'duration': 121.44,
#  'resolution': '320x240',
#  'subset': 'training',
#  'url': 'https://www.youtube.com/watch?v=5n7NCViB5TU'}

# %%
not tmp
# Out:
# True

# %%
tmp =gd_data['database']['v-LmMLpvsbk']['annotations'][0]['segment']

# %%
len(tmp)
# Out:
# 2

# %%
gd_data[list(gd_data.keys())[2]]['5n7NCViB5TU']['annotations']
# Out:
# [{'label': 'Discus throw', 'segment': [24.250181653524645, 38.08036312324492]},
#  {'label': 'Discus throw', 'segment': [62.14109007176286, 71.61381721684867]},
#  {'label': 'Discus throw', 'segment': [97.00072596567863, 106.28399856786271]}]

# %%
30 in [24.250181653524645, 38.08036312324492]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-9eb6a9c3975f> in <module>()
# ----> 1 30.0 in range(24.250181653524645, 38.08036312324492)
#
# TypeError: range() integer end argument expected, got float.

# %%
def _import_ground_truth(ground_truth_filename):
    """Reads ground truth file, checks if it is well formatted, and returns
       the ground truth instances and the activity classes.
    Parameters
    ----------
    ground_truth_filename : str
        Full path to the ground truth json file.
    Outputs
    -------
    ground_truth : df
        Data frame containing the ground truth instances.
    activity_index : dict
        Dictionary containing class index.
    """
    with open(ground_truth_filename, 'r') as fobj:
        data = json.load(fobj)
    # Checking format
#     if not all([field in data.keys() for field in self.gt_fields]):
#         raise IOError('Please input a valid ground truth file.')

    # Initialize data frame
    activity_index, cidx = {}, 0
    video_lst, label_lst = [], []
    for videoid, v in data['database'].items():
#         if self.subset != v['subset']:
#             continue
#         if videoid in self.blocked_videos:
#             continue
        for ann in v['annotations']:
            if ann['label'] not in activity_index:
                activity_index[ann['label']] = cidx
                cidx += 1
            video_lst.append(videoid)
            label_lst.append(activity_index[ann['label']])
#     ground_truth = pd.DataFrame({'video-id': video_lst,
#                                  'label': label_lst})
#     ground_truth = ground_truth.drop_duplicates().reset_index(drop=True)
#     return ground_truth, activity_index
    return activity_index,data

# %%
activity_index,json_data = _import_ground_truth('./activity_net.v1-3.min.json')

# %%
for i, batch in enumerate(list(json_data['database'])):
    print(json_data['database'][batch]['subset'])
# Out:
# training
# testing
# validation
# testing
# testing
# training
# training
# testing
# training
# training
# training
# training
# training
# validation
# validation
# validation
# testing
# validation
# training
# testing
# training
# training
# testing
# training
# validation
# training
# training
# validation
# training
# training
# training
# training
# training
# testing
# training
# testing
# training
# validation
# testing
# testing
# testing
# testing
# training
# training
# training
# validation
# training
# testing
# training
# training
# testing
# testing
# testing
# validation
# testing
# training
# training
# testing
# training
# training
# training
# training
# validation
# testing
# testing
# testing
# validation
# testing
# training
# testing
# training
# training
# training
# training
# testing
# testing
# validation
# validation
# testing
# validation
# training
# training
# validation
# testing
# testing
# testing
# validation
# training
# training
# testing
# ...

# %%
anno = gd_data['database']['EML38vJxknA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-8f4aa851a215> in <module>()
# ----> 1 anno = gd_data['database']['EML38vJxknA']
#
# KeyError: 'EML38vJxknA'

# %%
len(list(anno))
# Out:
# 0

# %%
gd_data['database']['5n7NCViB5TU']['duration']
# Out:
# 121.44

# %%
gd_data['database']
# Out:
# {'sJFgo9H6zNo': {'annotations': [{'label': 'Fun sliding down',
#     'segment': [0.01, 123.42336739937599]}],
#   'duration': 139.042,
#   'resolution': '640x360',
#   'subset': 'training',
#   'url': 'https://www.youtube.com/watch?v=sJFgo9H6zNo'},
#  'V1zhqaGFY2A': {'annotations': [],
#   'duration': 136.98,
#   'resolution': '658x480',
#   'subset': 'testing',
#   'url': 'https://www.youtube.com/watch?v=V1zhqaGFY2A'},
#  'JDg--pjY5gg': {'annotations': [{'label': 'Beer pong',
#     'segment': [61.420442338881465, 64.56014561469672]}],
#   'duration': 126.178,
#   'resolution': '1920x1080',
#   'subset': 'validation',
#   'url': 'https://www.youtube.com/watch?v=JDg--pjY5gg'},
#  'KsFid_YVsn0': {'annotations': [],
#   'duration': 235.13,
#   'resolution': '1920x1080',
#   'subset': 'testing',
#   'url': 'https://www.youtube.com/watch?v=KsFid_YVsn0'},
#  '-TmWR_keSfI': {'annotations': [],
#   'duration': 104.955,
#   'resolution': '1280x720',
#   'subset': 'testing',
# ...

# %%
import urllib.request

import numpy as np

API = 'http://ec2-52-11-11-89.us-west-2.compute.amazonaws.com/challenge17/api.py'

def get_blocked_videos(api=API):
    api_url = '{}?action=get_blocked'.format(api)
    req = urllib.request.Request(api_url)
    response = urllib.request.urlopen(req)
    return json.loads(response.read())

# %%
json_tmp= get_blocked_videos()

# %%
json_tmp
# Out:
# ['sjyZWmvTGA4',
#  'boWMu522Pfc',
#  'w2HnFjJei7k',
#  'x99PS_O6JW8',
#  'mQHY2uMOMP4',
#  'jCVi9xt3GUY',
#  'JG7T6qtO4jg',
#  'wmfI4aiJdH4',
#  'zLZTqSaGxJo',
#  'Wj7VGbIgjXE',
#  'uO9qoK8zGQc',
#  'hhE8W4Jo88I',
#  '-LtQMRfj0eM',
#  'plZs-3GtoOo',
#  'dl1RH5wfGGM',
#  'bVOD0M4LCEY',
#  'ILwwD00q1ZY',
#  'EwzkySgI6CQ',
#  'pf49xhMRrgQ',
#  '_j5JUQzOCtc',
#  'Hhzuzfdg6LY',
#  'HQdnIIRVqEk',
#  'Z1img-5JbDo',
#  'ns8v94HCtlM',
#  'x2J5RWf_LJk',
#  'YptHsVTHquc',
#  'JsoDi1QN4yk',
#  'IssfjAvSwo0',
#  'Pmt3R5olRP0',
#  'BTEv-FJHs8c',
#  '44TbmH7hgDc',
#  'yPsEMk0KMp4',
#  'PplBDkLlpEw',
#  'QvM8SFUUvsw',
#  '2F5aJzMxPSM',
#  '2Ci0ek9BNvg',
#  '5LveCNjz_zg',
#  'FeXBmKYV8HY',
#  'a2JBhm22-M4',
#  '0A-p1Q0rseE',
#  'yRup8RDsCzk',
#  'bV1UAhMjq5M',
#  'KWeZbXoX8Ys',
#  '0xtS7g7vZLU',
#  '2JyEK7sKsrY',
#  'ByDsWCKyWlo',
#  'LXHc1X1pKEM',
#  'PVdd6E1S0Yc',
#  'ZLmoqxkCJL0',
#  '8w9pf_Ecm_U',
#  'bIxkfJuPGIU',
#  'phEu4AcX3go',
#  'xH7qxBIz-tU',
#  'mz2-lgoNz1M',
#  'fxgbk_Kk4Rw',
# ...

# %% [markdown]
# ## Test full tfrecord

# %%
# Untrimmed
filenames = gfile.Glob(os.path.join('./output_tmp/videos_full/5n7NCViB5TU', '5n7NCViB5TU.tfrecords'))
filename_queue = tf.train.string_input_producer(filenames, shuffle=False)
reader = tf.TFRecordReader()
serialized_key, serialized_example = reader.read(filename_queue)
features = tf.parse_single_example(serialized_example, features={  
    'number_of_frames': tf.FixedLenFeature([], tf.int64),
    'label_index': tf.VarLenFeature(tf.int64),
    'label_name': tf.VarLenFeature(tf.string),
    'subset': tf.FixedLenFeature([], tf.string),
    'resolution': tf.FixedLenFeature([], tf.string),
    'video': tf.FixedLenFeature([], tf.string),
    'duration': tf.FixedLenFeature([], tf.string),
    'images': tf.VarLenFeature(tf.string),
    'flow_x': tf.VarLenFeature(tf.string),
    'flow_y': tf.VarLenFeature(tf.string),
    'audio': tf.FixedLenFeature([], tf.string)
    })

# %%
# Trimmed
filenames = gfile.Glob(os.path.join('./output_tmp/videos_full/5n7NCViB5TU', '5n7NCViB5TU.tfrecords'))
filename_queue = tf.train.string_input_producer(filenames, shuffle=False)
reader = tf.TFRecordReader()
serialized_key, serialized_example = reader.read(filename_queue)
features = tf.parse_single_example(serialized_example, features={  
    'number_of_frames': tf.FixedLenFeature([], tf.int64),
    'label_index': tf.FixedLenFeature([], tf.int64),
    'label_name': tf.FixedLenFeature([], tf.string),
    'subset': tf.FixedLenFeature([], tf.string),
    'resolution': tf.FixedLenFeature([], tf.string),
    'video': tf.FixedLenFeature([], tf.string),
    'duration': tf.FixedLenFeature([], tf.string),
    'images': tf.VarLenFeature(tf.string),
    'flow_x': tf.VarLenFeature(tf.string),
    'flow_y': tf.VarLenFeature(tf.string),
    'audio': tf.FixedLenFeature([], tf.string)
    })

# %%
# Untrimmed
images = features['images']
flow_x = features['flow_x']
flow_y = features['flow_y']
frames = tf.cast(features['number_of_frames'], tf.int32)
label_index = tf.cast(tf.sparse_tensor_to_dense(features['label_index']), tf.int32)
images_shape = tf.parallel_stack([frames])
images = tf.reshape(images.values, images_shape)
flow_x = tf.reshape(flow_x.values, images_shape)
flow_y = tf.reshape(flow_y.values, images_shape)
label_name = features['label_name'].values
subset = features['subset']
resolution = features['resolution']
video = features['video']
audio = tf.decode_raw(features['audio'], tf.float32)
duration = tf.decode_raw(features['duration'], tf.float32)

# %%
# Trimmed
images = features['images']
flow_x = features['flow_x']
flow_y = features['flow_y']
frames = tf.cast(features['number_of_frames'], tf.int32)
label_index = tf.cast(features['label_index'], tf.int32)
images_shape = tf.parallel_stack([frames])
images = tf.reshape(images.values, images_shape)
flow_x = tf.reshape(flow_x.values, images_shape)
flow_y = tf.reshape(flow_y.values, images_shape)
label_name = features['label_name']
subset = features['subset']
resolution = features['resolution']
video = features['video']
audio = tf.decode_raw(features['audio'], tf.float32)
duration = tf.decode_raw(features['duration'], tf.float32)

# %%
frame_nums = 16
start = tf.random_uniform(frames.shape, minval=0, maxval=frames-frame_nums, dtype=tf.int32, seed=None, name=None)
image_list = []
flow_x_list = []
flow_y_list = []
for i in range(frame_nums):
    image_raw = tf.image.decode_jpeg(images[start+i], channels=3)
    image_list.append(image_raw)
    flow_x_raw = tf.image.decode_jpeg(flow_x[start+i], channels=3)
    flow_x_list.append(flow_x_raw)
    flow_y_raw = tf.image.decode_jpeg(flow_y[start+i], channels=3)
    flow_y_list.append(flow_y_raw)

# %%
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)
    print("Write cropped and resized image to the folder './resized_image'") 
    for i in range(10): # number of examples in your tfrecord
#         images_run = sess.run(images)
#         pre_image = sess.run(image_raw)
        image_list_,flow_x_list_,flow_y_list_, frames_, label_index_, label_name_, subset_, resolution_, video_, audio_, duration_ = sess.run([image_list,flow_x_list,flow_y_list, frames, label_index, label_name, subset, resolution, video, audio, duration])
#         img = Image.fromarray(pre_image, "RGB")
#         print(img.shape)
#         imshow(img)
#         if not os.path.isdir("./resized_image/"):
#             os.mkdir("./resized_image")
#         img.save(os.path.join("./resized_image/class_"+str(pre_label)+"_Index_"+str(i)+".jpeg"))
#         if i % 10 == 0:
#             print ("%d images in %d has finished!" % (i, FLAGS.image_number))
#     print("Complete!!")
    coord.request_stop()
    coord.join(threads)
    sess.close()
# Out:
# Write cropped and resized image to the folder './resized_image'

# %%
label_name_
# Out:
# array([b'Discus throw', b'Discus throw', b'Discus throw'], dtype=object)

# %%
imshow(flow_x_list_[0][:,:,0], cmap='gray')

# %%
imshow(flow_y_list_[9][:,:,0], cmap='gray')

# %%
imshow(image_list_[9])

# %%
audio_.shape
# Out:
# (286650,)

# %%
frames_
# Out:
# 156

# %%
print(frames_, label_index_, label_name_, subset_, resolution_, video_)
# Out:
# 96 86 b'Discus throw' b'training' b'320x240' b'5n7NCViB5TU'

# %%
img = Image.fromarray(image_list_[9], "RGB")
imshow(img)

# %%
len(image_list_)
# Out:
# 16

# %% [markdown]
# ## Audio Test

# %%
import librosa

# %%
audio,r = librosa.load('./samples/5n7NCViB5TU.mp4',sr=22050,mono=False)

# %%
audio.shape
# Out:
# (2, 2676704)

# %%
from tensorflow.contrib import ffmpeg

audio_binary = tf.read_file('./samples/5n7NCViB5TU.mp4')
waveform = ffmpeg.decode_audio(
    audio_binary, file_format='mp4', samples_per_second=22050, channel_count=1)

# %%
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    audio_out = sess.run(waveform)

# %%
audio_out.shape
# Out:
# (2677760, 1)

# %%
audio[audio<-1.0] = -1.0
audio[audio>1.0] = 1.0

# %%
audio.min()
# Out:
# -1.0

# %%
audio_diff = audio - audio_out[:,0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-259-09f0cf26d990> in <module>()
# ----> 1 audio_diff = audio - audio_out[:,0]
#
# ValueError: operands could not be broadcast together with shapes (2676704,) (2677760,)

# %%
local_config = {
            'load_size': 22050*20,
            'phase': 'extract'
            }

def preprocess(raw_audio,config=local_config):
    # Select first channel (mono)
    if len(raw_audio.shape) > 1:
        raw_audio = raw_audio[0]
        
    raw_audio[raw_audio<-1.0] = -1.0
    raw_audio[raw_audio>1.0] = 1.0

    # Make range [-256, 256]
    raw_audio *= 256.0

    # Make minimum length available
    length = config['load_size']
    if length > raw_audio.shape[0]:
        raw_audio = np.tile(raw_audio, length/raw_audio.shape[0] + 1)

    # Check conditions
    assert len(raw_audio.shape) == 1, "It seems this audio contains two channels, we only need the first channel"
    assert np.max(raw_audio) <= 256, "It seems this audio contains signal that exceeds 256"
    assert np.min(raw_audio) >= -256, "It seems this audio contains signal that exceeds -256"

    # Shape to 1 x DIM x 1 x 1
#     raw_audio = np.reshape(raw_audio, [1, -1, 1, 1])

    return raw_audio.copy()

# %%
preprocessed_audio = preprocess(audio)

# %%
preprocessed_audio.shape[0]
# Out:
# 2676704

# %%
image_raw = tf.gfile.FastGFile('./images/5n7NCViB5TU/frame01286.jpg', 'rb').read()
image_raw = tf.image.decode_jpeg(image_raw, channels=3)

# %%
frame = cv2.imread('./images/5n7NCViB5TU/frame01286.jpg')
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
frame.dtype
# imshow(frame, cmap='gray')
# print(frame.shape)
# img = Image.fromarray(frame, "L")
# imshow(img)
# frame.min()
# Out:
# dtype('uint8')

# %%
optical_flow = cv2.DualTVL1OpticalFlow_create()
prev_frame = cv2.imread('./images/5n7NCViB5TU/frame01286.jpg')
prev_frame = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
cur_frame = cv2.imread('./images/5n7NCViB5TU/frame01287.jpg')
cur_frame = cv2.cvtColor(cur_frame, cv2.COLOR_BGR2GRAY)
flow = optical_flow.calc(prev_frame, cur_frame, None)

# %%
flow[flow >= 20] = 20
flow[flow <= -20] = -20

# %%
flow_tmp = flow.copy()

# %%
flow_tmp = flow_tmp + 20

# %%
data = flow_tmp / 40 # normalize the data to 0 - 1
data = 255 * data # Now scale by 255
img = data.astype(np.uint8)
imshow(img[:,:,1], cmap='gray')

# %%
img_encode = cv2.imencode('.jpg', img[:,:,0])[1]

# %%
img_encode = img_encode.tostring()

# %%
image_raw = tf.image.decode_jpeg(img_encode, channels=0)

# %%
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)
    print("Write cropped and resized image to the folder './resized_image'") 
    for i in range(10): # number of examples in your tfrecord
#         images_run = sess.run(images)
        pre_image = sess.run(image_raw)
#         image_list_ = sess.run(image_list)
#         img = Image.fromarray(pre_image, "RGB")
#         print(img.shape)
        imshow(pre_image[:,:,0], cmap='gray')
#         if not os.path.isdir("./resized_image/"):
#             os.mkdir("./resized_image")
#         img.save(os.path.join("./resized_image/class_"+str(pre_label)+"_Index_"+str(i)+".jpeg"))
#         if i % 10 == 0:
#             print ("%d images in %d has finished!" % (i, FLAGS.image_number))
#     print("Complete!!")
    coord.request_stop()
    coord.join(threads)
    sess.close()
# Out:
# Write cropped and resized image to the folder './resized_image'

# %%
pre_image.shape
# Out:
# (240, 320, 1)

# %%
print('aa {:04d}, bb {:04d}'.format(1,2))
# Out:
# aa 0001, bb 0002

# %% [markdown]
# ## Tensorflow Test

# %%
sess = tf.InteractiveSession()
tf_tmp = tf.random_uniform([1],minval=0,maxval=1)
tmp = tf_tmp.eval()

# %%
tmp.shape
# Out:
# (1,)
